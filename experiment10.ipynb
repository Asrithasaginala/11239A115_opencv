# %% [markdown]
# <a href="https://colab.research.google.com/github/Asrithasaginala/11239A115_opencv/blob/main/experiment10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python matplotlib

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files
import matplotlib.pyplot as plt

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dec8e219-05ba-4768-8008-7156cc97901b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dec8e219-05ba-4768-8008-7156cc97901b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d97bd288-608e-4a50-88ec-1d6cde2a6545" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d97bd288-608e-4a50-88ec-1d6cde2a6545">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('img_upload.jpg')   # change filename
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=500x500>

# %%
plt.title("Grayscale Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

plt.hist(gray.ravel(), 256, [0,256])
plt.show()
# Out:
# /tmp/ipykernel_2067/3349579578.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gray.ravel(), 256, [0,256])

# %%
colors = ('b', 'g', 'r')

for i, col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0,256])
    plt.plot(hist, color=col)

plt.title("RGB Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.show()

# %%
equalized = cv2.equalizeHist(gray)
cv2_imshow(equalized)
# Out:
# <PIL.Image.Image image mode=L size=500x500>

# %%
plt.title("Equalized Histogram")
plt.hist(equalized.ravel(), 256, [0,256])
plt.show()
# Out:
# /tmp/ipykernel_2067/1995093400.py:2: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(equalized.ravel(), 256, [0,256])

# %%
cv2_imshow(gray)
cv2_imshow(equalized)
# Out:
# <PIL.Image.Image image mode=L size=500x500>
# <PIL.Image.Image image mode=L size=500x500>
